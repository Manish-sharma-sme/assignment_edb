# %%
#Import necessary Libraries
import pandas as pd
import numpy as np

# %%
dt=pd.read_csv('C:\\Users\\Manish\\Desktop\\aspy\\training-train\\train.csv')

# %%
dt.head()
# Out:
#        Country  Life expectancy  Adult Mortality  infant deaths  Alcohol  \
# 0  Afghanistan             65.0              263           62.0     0.01
# 1  Afghanistan             59.9              271           64.0     0.01
# 2  Afghanistan             59.9              268           66.0     0.01
# 3  Afghanistan             59.5              272           69.0     0.01
# 4  Afghanistan             59.2              275           71.0     0.01
#
#    percentage expenditure  Measles   BMI  under-five deaths  \
# 0               71.279624   1154.0  19.1               83.0
# 1               73.523582    492.0  18.6               86.0
# 2               73.219243    430.0  18.1               89.0
# 3               78.184215   2787.0  17.6               93.0
# 4                7.097109   3013.0  17.2               97.0
#
#    Total expenditure         GDP  Population  Schooling
# 0               8.16  584.259210  33736494.0       10.1
# ...

# %%
#drop Country colmnn
dt.pop('Country')
#dt.drop(["Country"],axis=1)
# Out:
# 0     Afghanistan
# 1     Afghanistan
# 2     Afghanistan
# 3     Afghanistan
# 4     Afghanistan
#          ...
# 94      Argentina
# 95      Argentina
# 96        Armenia
# 97        Armenia
# 98        Armenia
# Name: Country, Length: 99, dtype: object

# %%
#Rename columns
dt.rename(columns={"Life expectancy":"Life_expectancy","Adult Mortality": "Adult_Mortality", "percentage expenditure": "Percentage_Exp"})
# Out:
#     Life_expectancy  Adult_Mortality  infant deaths  Alcohol  Percentage_Exp  \
# 0              65.0              263           62.0     0.01       71.279624
# 1              59.9              271           64.0     0.01       73.523582
# 2              59.9              268           66.0     0.01       73.219243
# 3              59.5              272           69.0     0.01       78.184215
# 4              59.2              275           71.0     0.01        7.097109
# ..              ...              ...            ...      ...             ...
# 94             74.0              138           12.0     7.76      123.012867
# 95             74.1              137           12.0     7.68     1349.025282
# 96             74.8              118            1.0      NaN        0.000000
# 97             74.6               12            1.0     3.91      295.608714
# 98             74.4              123            1.0     3.79      279.429081
#
# ...

# %%
#drop_duplicates considering all rows
dt.drop_duplicates()
# Out:
#     Life expectancy  Adult Mortality  infant deaths  Alcohol  \
# 0              65.0              263           62.0     0.01
# 1              59.9              271           64.0     0.01
# 2              59.9              268           66.0     0.01
# 3              59.5              272           69.0     0.01
# 4              59.2              275           71.0     0.01
# ..              ...              ...            ...      ...
# 94             74.0              138           12.0     7.76
# 95             74.1              137           12.0     7.68
# 96             74.8              118            1.0      NaN
# 97             74.6               12            1.0     3.91
# 98             74.4              123            1.0     3.79
#
#     percentage expenditure  Measles   BMI  under-five deaths  \
# 0                71.279624   1154.0  19.1               83.0
# 1                73.523582    492.0  18.6               86.0
# ...

# %%
#Droping duplicates on basis of  specific column
'''dt.drop_duplicates(subset="Alcohol",keep =False,inplace=True)'''
# Out:
# 'dt.drop_duplicates(subset="Alcohol",keep =False,inplace=True)'

# %%
#Droping Null values
dt=dt.dropna()

# %%
#droping data and setting Indices again
dt=dt.reset_index(drop=True)
dt
# Out:
#     Life expectancy  Adult Mortality  infant deaths  Alcohol  \
# 0              65.0              263           62.0     0.01
# 1              59.9              271           64.0     0.01
# 2              59.9              268           66.0     0.01
# 3              59.5              272           69.0     0.01
# 4              58.8              279           74.0     0.01
# ..              ...              ...            ...      ...
# 60             74.1              138           12.0     7.81
# 61             74.0              138           12.0     7.76
# 62             74.1              137           12.0     7.68
# 63             74.6               12            1.0     3.91
# 64             74.4              123            1.0     3.79
#
#     percentage expenditure  Measles   BMI  under-five deaths  \
# 0                71.279624   1154.0  19.1               83.0
# 1                73.523582    492.0  18.6               86.0
# ...

# %%
#Saving a DataFrame to csv
dt.to_csv('eval.csv')

# %% [markdown]
# # problem 3

# %%
df=pd.read_csv('https://media-doselect.s3.amazonaws.com/generic/BgR3v70YJORZ4Mor3zo3ALPP7/training-iris.zip')

# %%
df
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 0             1           5.1          3.5           1.4          0.2
# 1             2           4.9          3.0           1.4          0.2
# 2             3           4.7          3.2           1.3          0.2
# 3             4           4.6          3.1           1.5          0.2
# 4             5           5.0          3.6           1.4          0.2
# ..          ...           ...          ...           ...          ...
# 145         146           6.7          3.0           5.2          2.3
# 146         147           6.3          2.5           5.0          1.9
# 147         148           6.5          3.0           5.2          2.0
# 148         149           6.2          3.4           5.4          2.3
# 149         150           5.9          3.0           5.1          1.8
#
#        Species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# ...

# %%
df
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 0             1           5.1          3.5           1.4          0.2
# 1             2           4.9          3.0           1.4          0.2
# 2             3           4.7          3.2           1.3          0.2
# 3             4           4.6          3.1           1.5          0.2
# 4             5           5.0          3.6           1.4          0.2
# ..          ...           ...          ...           ...          ...
# 145         146           6.7          3.0           5.2          2.3
# 146         147           6.3          2.5           5.0          1.9
# 147         148           6.5          3.0           5.2          2.0
# 148         149           6.2          3.4           5.4          2.3
# 149         150           5.9          3.0           5.1          1.8
#
#        Species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# ...

# %%
df['Sepal.Area']=df['Sepal.Length']*df['Sepal.Width']

# %%
df
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 0             1           5.1          3.5           1.4          0.2
# 1             2           4.9          3.0           1.4          0.2
# 2             3           4.7          3.2           1.3          0.2
# 3             4           4.6          3.1           1.5          0.2
# 4             5           5.0          3.6           1.4          0.2
# ..          ...           ...          ...           ...          ...
# 145         146           6.7          3.0           5.2          2.3
# 146         147           6.3          2.5           5.0          1.9
# 147         148           6.5          3.0           5.2          2.0
# 148         149           6.2          3.4           5.4          2.3
# 149         150           5.9          3.0           5.1          1.8
#
#        Species  Sepal.Area
# 0       setosa       17.85
# 1       setosa       14.70
# 2       setosa       15.04
# ...

# %%
sbst=df[['Sepal.Length', 'Sepal.Width', 'Sepal.Area','Species']]

# %%
sbst.head()
# Out:
#    Sepal.Length  Sepal.Width  Sepal.Area Species
# 0           5.1          3.5       17.85  setosa
# 1           4.9          3.0       14.70  setosa
# 2           4.7          3.2       15.04  setosa
# 3           4.6          3.1       14.26  setosa
# 4           5.0          3.6       18.00  setosa

# %%
abv_22=sbst[sbst['Sepal.Area']>22]

# %%
abv_22
# Out:
#      Sepal.Length  Sepal.Width  Sepal.Area     Species
# 14            5.8          4.0       23.20      setosa
# 15            5.7          4.4       25.08      setosa
# 33            5.5          4.2       23.10      setosa
# 50            7.0          3.2       22.40  versicolor
# 105           7.6          3.0       22.80   virginica
# 109           7.2          3.6       25.92   virginica
# 117           7.7          3.8       29.26   virginica
# 120           6.9          3.2       22.08   virginica
# 124           6.7          3.3       22.11   virginica
# 125           7.2          3.2       23.04   virginica
# 131           7.9          3.8       30.02   virginica
# 135           7.7          3.0       23.10   virginica
# 144           6.7          3.3       22.11   virginica

# %%
abv_22.to_csv("filtered_data.csv",index=False)

# %% [markdown]
# # Problem 2

# %%
df1=pd.read_csv('https://media-oselect.s3.amazonaws.com/generic/Y2RNG9jW1MZOO71LLP1RZXeBJ/training-P2.zip')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24368/3775204767.py in <module>
# ----> 1 df1=pd.read_csv('https://media-oselect.s3.amazonaws.com/generic/Y2RNG9jW1MZOO71LLP1RZXeBJ/training-P2.zip')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
